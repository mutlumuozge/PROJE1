# %%
# !pip install ipynb
# !pip install numpy

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import datetime as dt

# %%
df0 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_230107.txt')
df0 = pd.DataFrame(df0)

# %%
df1 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_230114.txt')
df1 = pd.DataFrame(df1)

# %%
df2= pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_230121.txt')
df2= pd.DataFrame(df2)

# %%
df3= pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_230128.txt')
df3= pd.DataFrame(df3)

# %%
df4= pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_230204.txt')
df4= pd.DataFrame(df4)

# %%
df5= pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_230211.txt')
df5= pd.DataFrame(df5)

# %%
df6= pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_230218.txt')
df6= pd.DataFrame(df6)

# %%
df7= pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_230225.txt')
df7= pd.DataFrame(df7)

# %%
df8 =pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_230304.txt')
df8= pd.DataFrame(df8)

# %%
df9 =pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_230311.txt')
df9= pd.DataFrame(df9)

# %%
df10 =pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_230318.txt')
df10= pd.DataFrame(df10)

# %%
df = pd.concat([df0, df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df10],ignore_index = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2528113 entries, 0 to 2528112
# Data columns (total 11 columns):
#  #   Column                                                                Dtype
# ---  ------                                                                -----
#  0   C/A                                                                   object
#  1   UNIT                                                                  object
#  2   SCP                                                                   object
#  3   STATION                                                               object
#  4   LINENAME                                                              object
#  5   DIVISION                                                              object
#  6   DATE                                                                  object
#  7   TIME                                                                  object
# ...

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/31/2022  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/31/2022  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/31/2022  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/31/2022  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/31/2022  19:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7811594
# 1  REGULAR  7811598
# 2  REGULAR  7811625
# 3  REGULAR  7811696
# 4  REGULAR  7811815
#
#    EXITS
# 0                                            2771224
# 1                                            2771239
# 2                                            2771306
# 3                                            2771355
# 4                                            2771390

# %%
df.sample(40)
# Out:
#           C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 1407033  R143  R032  02-00-02   TIMES SQ-42 ST  1237ACENQRSW      IRT
# 882076   H026  R137  00-03-02   MYRTLE-WYCKOFF            LM      BMT
# 2201343  N336  R158  00-03-02      KEW GARDENS            EF      IND
# 623742   R605  R456  00-00-03          HOYT ST            23      IRT
# 833465   R551  R072  01-03-07  34 ST-HUDSON YD             7      IRT
# 656497   C009  R057  03-05-01   ATL AV-BARCLAY     BDNQR2345      BMT
# 295588   N318  R298  00-00-00    NORTHERN BLVD            MR      IND
# 473694   N035  R334  00-00-02   CATHEDRAL PKWY            BC      IND
# 1232072  R307  R207  01-00-02           135 ST            23      IRT
# 663718   E001  R368  00-05-00             9 AV             D      BMT
# 1710214  C009  R057  03-03-00   ATL AV-BARCLAY     BDNQR2345      BMT
# 826546   R521  R327  00-00-00            52 ST             7      IRT
# ...

# %%
df.tail()
# Out:
#            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 2528108  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/17/2023
# 2528109  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/17/2023
# 2528110  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/17/2023
# 2528111  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/17/2023
# 2528112  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/17/2023
#
#              TIME     DESC  ENTRIES  \
# 2528108  05:00:00  REGULAR        0
# 2528109  09:00:00  REGULAR        0
# 2528110  13:00:00  REGULAR        0
# 2528111  17:00:00  REGULAR        0
# 2528112  21:00:00  REGULAR        0
#
#          EXITS
# 2528108                                               1117
# 2528109                                               1117
# 2528110                                               1117
# 2528111                                               1117
# ...

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')
